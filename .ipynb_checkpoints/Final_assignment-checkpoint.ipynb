# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("primates-morphology.csv")

# %%
df
# Out:
#      Unnamed: 0           0           1          2          3          4  \
# 0         37773  133.426742 -101.627603  21.125902 -11.518251   4.621089
# 1         37772  145.344740 -108.229812  21.121390 -14.982879   2.299335
# 2         22276  137.773342 -107.162743  18.232497 -17.116294   3.016809
# 3         37776  141.523739 -107.436626  17.448083 -16.861469   3.382894
# 4         37777  142.357906  -97.195294  10.511391  -6.520641   3.555506
# ..          ...         ...         ...        ...        ...        ...
# 160       41421  -91.085462  -46.160638  86.488654  16.969797   8.581993
# 161       41416  -91.489354  -39.614165  87.430951  20.871706  11.444575
# 162       41414  -90.204104  -40.985982  83.286250  19.714259  10.448984
# 163       41412  -90.248202  -50.111180  77.285086  19.578454   5.634918
# 164       41411  -88.663448  -43.835382  74.681197  19.086880   9.755993
#
#              5         6         7         8  ...        25        26  \
# 0    -1.519551  0.583410 -7.182875  1.410030  ... -0.301822 -0.433051
# 1    -2.354040  0.431199 -5.266930 -1.424469  ...  0.215340 -0.299550
# 2    -5.295234  1.716895 -1.668914 -1.917478  ... -0.481468 -0.243025
# 3    -1.071286  1.768891 -2.735232 -1.136700  ...  0.586941 -0.043639
# 4     1.652390 -0.655919 -5.373075 -1.466841  ...  0.653851  0.718319
# ..         ...       ...       ...       ...  ...       ...       ...
# 160  -8.889106  3.806365 -2.572926 -1.852834  ...  0.360452  0.513323
# 161  -6.707486  1.910320 -5.616304 -3.878495  ... -0.368755 -0.173323
# 162 -10.269775  4.749293 -2.725633 -1.577457  ... -0.033229  0.434486
# 163 -13.863556  1.840409 -0.507864 -1.227452  ...  0.125275 -0.018511
# 164  -9.499983  2.948722 -2.992005 -0.666312  ...  0.141954 -0.947492
#
#            27        28        29  Abbreviation      Genus    Species  Sex  \
# 0    0.037651 -0.279618 -0.421040            Ph  Presbytis      hosei    U
# 1    0.709472  0.876382 -0.150133            Ph  Presbytis      hosei    F
# 2   -0.537644 -0.140292  0.082158            Pr  Presbytis  rubicunda    U
# 3   -0.518699 -1.051100  0.542354            Pr  Presbytis  rubicunda    M
# 4    0.798722 -0.396749  0.844772            Pr  Presbytis  rubicunda    F
# ..        ...       ...       ...           ...        ...        ...  ...
# 160  0.043604  0.294724 -0.003514            Hl  Hylobates        lar    F
# 161 -0.627292  0.092090  0.444992            Hl  Hylobates        lar    F
# 162 -0.158110 -0.416191  0.160474            Hl  Hylobates        lar    F
# 163  0.080169 -0.235063  0.317110            Hl  Hylobates        lar    F
# 164  0.060862 -0.297479  0.723835            Hl  Hylobates        lar    F
#
#      Age
# 0      A
# 1      A
# 2      A
# 3      A
# 4      A
# ..   ...
# 160    A
# 161    A
# 162    A
# 163    A
# 164    A
#
# [165 rows x 36 columns]

# %%
df = df.set_index(df.columns[0])

# %%
df
# Out:
#                      0           1          2          3          4  \
# Unnamed: 0
# 37773       133.426742 -101.627603  21.125902 -11.518251   4.621089
# 37772       145.344740 -108.229812  21.121390 -14.982879   2.299335
# 22276       137.773342 -107.162743  18.232497 -17.116294   3.016809
# 37776       141.523739 -107.436626  17.448083 -16.861469   3.382894
# 37777       142.357906  -97.195294  10.511391  -6.520641   3.555506
# ...                ...         ...        ...        ...        ...
# 41421       -91.085462  -46.160638  86.488654  16.969797   8.581993
# 41416       -91.489354  -39.614165  87.430951  20.871706  11.444575
# 41414       -90.204104  -40.985982  83.286250  19.714259  10.448984
# 41412       -90.248202  -50.111180  77.285086  19.578454   5.634918
# 41411       -88.663448  -43.835382  74.681197  19.086880   9.755993
#
#                     5         6         7         8         9  ...        25  \
# Unnamed: 0                                                     ...
# 37773       -1.519551  0.583410 -7.182875  1.410030  0.216411  ... -0.301822
# 37772       -2.354040  0.431199 -5.266930 -1.424469 -1.451953  ...  0.215340
# 22276       -5.295234  1.716895 -1.668914 -1.917478  0.601120  ... -0.481468
# 37776       -1.071286  1.768891 -2.735232 -1.136700 -2.706925  ...  0.586941
# 37777        1.652390 -0.655919 -5.373075 -1.466841 -2.626544  ...  0.653851
# ...               ...       ...       ...       ...       ...  ...       ...
# 41421       -8.889106  3.806365 -2.572926 -1.852834 -0.197013  ...  0.360452
# 41416       -6.707486  1.910320 -5.616304 -3.878495 -0.037360  ... -0.368755
# 41414      -10.269775  4.749293 -2.725633 -1.577457  2.706787  ... -0.033229
# 41412      -13.863556  1.840409 -0.507864 -1.227452  0.595468  ...  0.125275
# 41411       -9.499983  2.948722 -2.992005 -0.666312  0.333317  ...  0.141954
#
#                   26        27        28        29  Abbreviation      Genus  \
# Unnamed: 0
# 37773      -0.433051  0.037651 -0.279618 -0.421040            Ph  Presbytis
# 37772      -0.299550  0.709472  0.876382 -0.150133            Ph  Presbytis
# 22276      -0.243025 -0.537644 -0.140292  0.082158            Pr  Presbytis
# 37776      -0.043639 -0.518699 -1.051100  0.542354            Pr  Presbytis
# 37777       0.718319  0.798722 -0.396749  0.844772            Pr  Presbytis
# ...              ...       ...       ...       ...           ...        ...
# 41421       0.513323  0.043604  0.294724 -0.003514            Hl  Hylobates
# 41416      -0.173323 -0.627292  0.092090  0.444992            Hl  Hylobates
# 41414       0.434486 -0.158110 -0.416191  0.160474            Hl  Hylobates
# 41412      -0.018511  0.080169 -0.235063  0.317110            Hl  Hylobates
# 41411      -0.947492  0.060862 -0.297479  0.723835            Hl  Hylobates
#
#               Species  Sex  Age
# Unnamed: 0
# 37773           hosei    U    A
# 37772           hosei    F    A
# 22276       rubicunda    U    A
# 37776       rubicunda    M    A
# 37777       rubicunda    F    A
# ...               ...  ...  ...
# 41421             lar    F    A
# 41416             lar    F    A
# 41414             lar    F    A
# 41412             lar    F    A
# 41411             lar    F    A
#
# [165 rows x 35 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
y = np.array(df["Species"])
X = np.array(df.iloc[:, 0:30])

X.shape
# Out:
# (165, 30)

# %%
#normalizing the X
from sklearn.preprocessing import StandardScaler

def normalize(X):
    scalar = StandardScaler()
    scalar = scalar.fit(X)
    X = scalar.transform(X)
    return X

X = normalize(X)

# %%
from sklearn.model_selection import train_test_split, ShuffleSplit
#split the set into 2 groups, Training and Test/Validation
test_size = 0.3
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size)
